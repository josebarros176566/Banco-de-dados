# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import requests
url = "https://www.kaggle.com/rishidamarla/cancer-patients-data/version/1?select=cancer+patient+data+sets.xlsx"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <title>Cancer Patients Data | Kaggle</title>
#   <meta charset="utf-8" />
#   <meta name="robots" content="index, follow" />
#   <meta name="description" content="Data from numerous cancer patients." />
#   <meta name="turbolinks-cache-control" content="no-cache" />
#     <meta name="keywords" content="health,cancer,beginner,data visualization,diseases" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#   <meta name="theme-color" content="#008ABC" />
#   <script nonce="meFVItUTWfZiRY61kiaqig==" type="text/javascript">
#     window["pageRequestStartTime"] = 1629562969928;
#     window["pageRequestEndTime"] = 1629562970045;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# ...

# %%
import requests
url = "https://www.kaggle.com/gpreda/covid-world-vaccination-progress?select=country_vaccinations.csv"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <title>COVID-19 World Vaccination Progress | Kaggle</title>
#   <meta charset="utf-8" />
#   <meta name="robots" content="index, follow" />
#   <meta name="description" content="Daily and Total Vaccination for COVID-19 in the World from Our World in Data" />
#   <meta name="turbolinks-cache-control" content="no-cache" />
#     <meta name="keywords" content="health,biology,covid19,public safety,public health" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#   <meta name="theme-color" content="#008ABC" />
#   <script nonce="QFEYWELU/7ZVPDhNJ2ysQw==" type="text/javascript">
#     window["pageRequestStartTime"] = 1629563138285;
#     window["pageRequestEndTime"] = 1629563138532;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %%
![cancer e comorbidades](https://hub-binder.mybinder.ovh/user/santanche-lab2learn-u5ie4bin/view/templates/2021/lab01/images/lab1.png)
